# %%
import re
res ="_h1 _f1  Ok thanks. h1_\n _span _f2 To benefit from my intelligence, \
let's get connected to your business data. Below are some of the data sources I can provide business intelligence for. span_ _ol _f3 ol_ \
_span _f4 So which do you prefer? span_"

ol = ["quickbooks"]

tag_patterns = ['_h1', '_span', '_p', '_ol']
list_patterns = ['_ol']

def handle_welcome(res):
    name = 'Raymond'
    _h = []
    res = res.replace('_name', name).replace('\n', '<br />')
    found_tags = [tag for tag in tag_patterns if tag in res]
    
    for index, tag in enumerate(found_tags):
        end_tag = tag.split('_')[-1] + '_'
        temp = re.findall( f'{tag} (.*?) {end_tag}', res)
        if tag in list_patterns:
            flow_num = int(re.split('\D+', temp[0])[-1])
            _h.append({tag.split('_')[1]: ol, 'flow': flow_num})
        else:
            for index, p in enumerate(temp):
                msg = p.replace(p.split(' ')[0], '')
                flow_num = int(re.split('\D+', p.split(' ')[0])[-1])
                print(flow_num)
                _h.append({tag.split('_')[1]: msg.strip(), 'flow': flow_num})

    _h = sorted(_h, key = lambda i: i['flow']) 
    return _h
handle_welcome(res)
# Out:
# 1
# 2
# 4
# [{'h1': 'Ok thanks.', 'flow': 1},
#  {'span': "To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for.",
#   'flow': 2},
#  {'ol': ['quickbooks'], 'flow': 3},
#  {'span': 'So which do you prefer?', 'flow': 4}]

# %%
re.split('\D+', '_f21')
# Out:
# ['', '21']

# %%
h = 'today_revenue'
h.replace('_', ' ')
# Out:
# 'today revenue'

# %%
_h = [{1: 'Ok thanks.'},
 {2: "To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for."},
 {5: 'I love you'},
 {4: ['quickbooks']},
 {3: 'So which do you prefer?'}]
_a = [1,2,1]
_h.sort(key=lambda x: _a.index(list(x.keys())[0]))
print(_h)
# Out:
# [{1: 'Ok thanks.'}, {2: "To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for."}, {3: 'So which do you prefer?'}, {4: ['quickbooks']}, {5: 'I love you'}]

# %%
orders = {
'cappuccino': 54,
'latte': 56,
'espresso': 72,
'americano': 48,
'cortado': 41
}

sort_orders = sorted(orders.items(), key=lambda x: x[1])

for i in sort_orders:
	print(i[0], i[1])
# Out:
# cortado 41
# americano 48
# cappuccino 54
# latte 56
# espresso 72

# %%
res ="_h1 Ok thanks. h1_\n _span To benefit from my intelligence, \
let's get connected to your business data. Below are some of the data sources I can provide business intelligence for. span_ _ol \
_span So which do you prefer? span_ "

ol = ["quickbooks"]

tag_patterns = ['_h1', '_span', '_p', '_ol']
list_patterns = ['_ol']

def handle_welcome(res):
    name = 'Raymond'
    result = {}
    _h = []
    # Step 1: Replace all placeholders values
    res = res.replace('_name', name).replace('\n', '<br />')
    
#     found_tags = [tag for tag in tag_patterns if tag in res]
    res_ = res.split(' ')
    found_tags = [tag for tag in res_ if tag in tag_patterns]
    print(found_tags)

    for tag in found_tags:
        if tag in list_patterns:
            result[tag.split('_')[1]] = ol
        else:
            end_tag = tag.split('_')[-1] + '_'
            temp = re.findall(f'{tag} (.*?) {end_tag}', res)
            result[tag.split('_')[1]] = temp if len(temp) > 1 else temp[0].strip()
                
    return result
handle_welcome(res)
# Out:
# ['_h1', '_span', '_ol', '_span']
# {'h1': 'Ok thanks.',
#  'span': ["To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for.",
#   'So which do you prefer?'],
#  'ol': ['quickbooks']}

# %%
[x.group() for x in re.finditer( r'all (.*?) are', 'all cats are smarter than dogs, all dogs are dumber than cats')]

a = {'span': "To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for."}

a = list(a.keys())[0]
print(a)

import re

text = 'This is sample text to test if this pythonic '\
       'program can serve as an indexing platform for '\
       'finding words in a paragraph. It can give '\
       'values as to where the word is located with the '\
       'different examples as stated'

#  find all occurances of the word 'as' in the above text


find_the_word = re.finditer('_span', res)
for match in find_the_word:
    print('start {}, end {}, search string \'{}\''.
          format(match.start(), match.end(), match.group()))
    
print(res[20], res[193])

import random
a = [1,2,3,4,5]
print(a)
random.shuffle(a)
print(a)
# Out:
# span
# start 20, end 25, search string '_span'
# _
# [1, 2, 3, 4, 5]
# [3, 2, 5, 4, 1]

# %%
res ="_h1 Ok thanks.h1_\n _span To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for. span_ _span So which do you prefer? span_ _ol"

re.findall( r'_span (.*?) span_', res)
# [x.group() for x in re.finditer( r'all (.*?) are', 'all cats are smarter than dogs, all dogs are dumber than cats')]
# Out:
# ["To benefit from my intelligence, let's get connected to your business data. Below are some of the data sources I can provide business intelligence for.",
#  'So which do you prefer?']

# %%
from nltk.corpus import wordnet
def get_syn_of_word(word):
    synonyms = []
    antonyms = []

    for syn in wordnet.synsets(word):
        for l in syn.lemmas():
            synonyms.append(l.name())
            if l.antonyms():
                antonyms.append(l.antonyms()[0].name())
    synonyms = sorted(list(set(synonyms)))
    antonyms = sorted(list(set(synonyms)))
    print(synonyms)

get_syn_of_word('of course')
# Out:
# []

# %%
import warnings
warnings.filterwarnings('ignore')

import nltk
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

import numpy as np, pandas as pd, pickle, random, json, os, time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## First Timer Bot

# %%
"""First Timer Model"""
# with open('../datasets/first_timer.json') as data:
#     intents = json.load(data)
    
"""KPI Model"""
with open('../datasets/kpi.json') as data:
    intents = json.load(data)

words = []
classes = []
documents = []
ignore_words = ["?","!", "'s", "(", ")", ";"]

for intent in intents['intents']:
    for patterns in intent['patterns']:
        
        w = nltk.word_tokenize(patterns)
        words.extend(w)
        documents.append((w, intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))
dataset = [words, classes, documents]

"""First Timer Model"""
# try:
#     os.mkdir('./pickle')
#     pickle.dump(dataset, open('./pickle/first_timer.pkl', 'wb'))
# except FileExistsError as e:
#     pickle.dump(dataset, open('./pickle/first_timer.pkl', 'wb'))

"""KPI Model"""
try:
    os.mkdir('./pickle')
    pickle.dump(dataset, open('./pickle/kpi.pkl', 'wb'))
except FileExistsError as e:
    pickle.dump(dataset, open('./pickle/kpi.pkl', 'wb'))
    

    
    
    
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = [] 
    pattern_words = doc[0]
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]

    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
        
random.shuffle(training)
training = np.array(training)

train_x = list(training[:,0])
train_y = list(training[:,1])

"""First Timer Model"""
# pickle.dump(training, open(f'./pickle/first_timer_training.pkl', 'wb'))

"""KPI Model"""
pickle.dump(training, open(f'./pickle/kpi.pkl', 'wb'))




model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(np.array(train_x), np.array(train_y), epochs=300, batch_size=8, verbose=1)
# Out:
# Epoch 1/300
# 672/672 [==============================] - 0s 316us/step - loss: 3.2421 - accuracy: 0.1220
# Epoch 2/300
# 672/672 [==============================] - 0s 186us/step - loss: 2.7587 - accuracy: 0.2277
# Epoch 3/300
# 672/672 [==============================] - 0s 192us/step - loss: 2.2493 - accuracy: 0.3348
# Epoch 4/300
# 672/672 [==============================] - 0s 186us/step - loss: 1.8334 - accuracy: 0.4464
# Epoch 5/300
# 672/672 [==============================] - 0s 193us/step - loss: 1.5179 - accuracy: 0.5327
# Epoch 6/300
# 672/672 [==============================] - 0s 189us/step - loss: 1.2352 - accuracy: 0.6101
# Epoch 7/300
# 672/672 [==============================] - 0s 182us/step - loss: 1.0446 - accuracy: 0.6786
# Epoch 8/300
# 672/672 [==============================] - 0s 188us/step - loss: 0.9003 - accuracy: 0.7545
# Epoch 9/300
# 672/672 [==============================] - 0s 180us/step - loss: 0.7331 - accuracy: 0.7857
# Epoch 10/300
# ...

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))
def classify_local(sentence):
    ERROR_THRESHOLD = 0.25
    
    # generate probabilities from the model
    input_data = pd.DataFrame([bow(sentence, words, False)], dtype=float, index=['input'])
    results = model.predict([input_data])[0]
    # filter out predictions below a threshold, and provide intent index
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], str(r[1])))
    # return tuple of intent and probability
    
    return return_list

def chat():
    print("Start talking with bot. (type stop to quite)\n")
    print("\nBot: ",random.choice(["Hi _blank. \n Welcome to Univers. \n I'm Ramses, I'm here to get you started. \n Shall we proceed?"]))
    while True:
        inp = input("You: ")
        if inp.lower() == "stop":
            break
        
        result = classify_local(inp)[0]
        
        for tag in intents['intents']:
            if tag['tag'] == result[0]:
                response = [tag['responses'], tag['tag']]
        print('\n Bot: ',random.choice(response[0]), '\n', response[-1])

# %%
chat()
# Out:
# Start talking with bot. (type stop to quite)
#
#
# Bot:  Hi _blank.
#  Welcome to Univers.
#  I'm Ramses, I'm here to get you started.
#  Shall we proceed?
# You:  what is my forecast revenue for today
#  Bot:  Your forecast revenue for today is _forecast. This means, we are expected to make this amount by the end today and more. Nice
#  daily_forecast
# You:  paid invoice
#  Bot:  paid invoices
#  paid_invoice
# You:  how much have I receive from invoices
#  Bot:  paid invoices
#  paid_invoice
# You:  stop

# %%
classify_local('quickbooks')
# Out:
# [('proceed', '0.6596412')]

# %%
from textblob import TextBlob
import nltk
from nltk.tokenize import word_tokenize


sent = word_tokenize('why not')
print(nltk.pos_tag(sent))

# sentence = TextBlob("why ")
# sentence.sentiment
# Out:
# [('why', 'WRB'), ('not', 'RB')]

# %%
sentence = TextBlob("why not")
sentence.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
