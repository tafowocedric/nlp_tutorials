# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import pickle
import random
import json
import string

import tensorflow as tf
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.stem.lancaster import LancasterStemmer
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
with open('kpi.json') as file:
    data = json.load(file)

# %%
stemmer = LancasterStemmer()

# %%
words = []
classes = []
documents = []
ignore_words = ["'s"]
ignore_words.extend(string.punctuation)

try:
    with open('data.pickle', 'rb') as file:
        words, classes, documents = pickle.load(file)
except:
    # loop through each sentence in our intents pattern
    for intent in data['intents']:
        for pattern in intent['patterns']:
            # tokenize each word in the sentence
            wrds = nltk.word_tokenize(pattern)
            words.extend(wrds) # add to word list
            documents.append((wrds, intent['tag'])) # add to documents in our corpus

        if intent['tag'] not in classes:
            classes.append(intent['tag']) # add to our class list

    # stem and lower each word and remove duplicates
    words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
    words = sorted(list(set(words)))

    classes = sorted(list(set(classes))) # sort classes

    print(f"{len(documents)} documents\n{len(classes)} classes\n{len(words)} unique stemmed words")


    with open('data.pickle', 'wb') as file:
        pickle.dump((words, classes, documents), file)
        
# create our training data
training = []
output_empty = [0 for _ in range(len(classes))]

for doc in documents: # bag of words
    bag = []
    s_words = [stemmer.stem(w.lower()) for w in doc[0] if w not in ignore_words]
    
    for w in words:
        bag.append(1) if w in s_words else bag.append(0)
        
    output_row = output_empty[:]
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
    
# shuffle our features and turn intp np.array
random.shuffle(training)
training = np.array(training)

# create train and test list.
train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fit the model
model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 672/672 [==============================] - 2s 3ms/step - loss: 3.1302 - accuracy: 0.1384
# Epoch 2/200
# 672/672 [==============================] - 1s 903us/step - loss: 2.3691 - accuracy: 0.3110
# Epoch 3/200
# 672/672 [==============================] - 1s 953us/step - loss: 1.7194 - accuracy: 0.4598
# Epoch 4/200
# 672/672 [==============================] - 1s 940us/step - loss: 1.2927 - accuracy: 0.5938
# Epoch 5/200
# 672/672 [==============================] - 1s 1ms/step - loss: 1.0544 - accuracy: 0.6726
# Epoch 6/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.8172 - accuracy: 0.7560
# Epoch 7/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.6397 - accuracy: 0.8125
# Epoch 8/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.6153 - accuracy: 0.8185
# Epoch 9/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.8438
# Epoch 10/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.4934 - accuracy: 0.8408
# Epoch 11/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.4093 - accuracy: 0.8705
# Epoch 12/200
# 672/672 [==============================] - 1s 961us/step - loss: 0.4235 - accuracy: 0.8586
# Epoch 13/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.3868 - accuracy: 0.8676
# Epoch 14/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.3569 - accuracy: 0.8750
# Epoch 15/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.3562 - accuracy: 0.8720
# Epoch 16/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.3241 - accuracy: 0.8943
# Epoch 17/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.3054 - accuracy: 0.8929
# Epoch 18/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.2968 - accuracy: 0.9033
# Epoch 19/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.3059 - accuracy: 0.8943
# Epoch 20/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.2903 - accuracy: 0.9048
# Epoch 21/200
# 672/672 [==============================] - 1s 891us/step - loss: 0.2852 - accuracy: 0.8988
# Epoch 22/200
# 672/672 [==============================] - 1s 868us/step - loss: 0.2631 - accuracy: 0.9062
# Epoch 23/200
# 672/672 [==============================] - 1s 943us/step - loss: 0.3141 - accuracy: 0.8988
# Epoch 24/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.2393 - accuracy: 0.9256
# Epoch 25/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.
200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0947 - accuracy: 0.9613
# Epoch 117/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1036 - accuracy: 0.9583
# Epoch 118/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1456 - accuracy: 0.9479
# Epoch 119/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1144 - accuracy: 0.9568
# Epoch 120/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1406 - accuracy: 0.9479
# Epoch 121/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1468 - accuracy: 0.9509
# Epoch 122/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1594 - accuracy: 0.9405
# Epoch 123/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1211 - accuracy: 0.9509
# Epoch 124/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1255 - accuracy: 0.9539
# Epoch 125/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1234 - accuracy: 0.9479
# Epoch 126/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1368 - accuracy: 0.9494
# Epoch 127/200
# 672/672 [==============================] - 1s 925us/step - loss: 0.1058 - accuracy: 0.9643
# Epoch 128/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1073 - accuracy: 0.9643
# Epoch 129/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1127 - accuracy: 0.9554
# Epoch 130/200
# 672/672 [==============================] - 1s 966us/step - loss: 0.0998 - accuracy: 0.9643
# Epoch 131/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1053 - accuracy: 0.9613
# Epoch 132/200
# 672/672 [==============================] - 1s 989us/step - loss: 0.1044 - accuracy: 0.9583
# Epoch 133/200
# 672/672 [==============================] - 1s 995us/step - loss: 0.1056 - accuracy: 0.9583
# Epoch 134/200
# 672/672 [==============================] - 1s 995us/step - loss: 0.0954 - accuracy: 0.9628
# Epoch 135/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1108 - accuracy: 0.9494
# Epoch 136/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1179 - accuracy: 0.9568
# Epoch 137/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1243 - accuracy: 0.9464
# Epoch 138/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1026 - accuracy: 0.9583
# Epoch 139/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1188 - accuracy: 0.9479
# Epoch 140/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1124 - accuracy: 0.9539
# Epoch 141/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1085 - accuracy: 0.9583
# Epoch 142/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0861 - accuracy: 0.9628
# Epoch 143/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1196 - accuracy: 0.9464
# Epoch 144/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1054 - accuracy: 0.9598
# Epoch 145/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1233 - accuracy: 0.9464
# Epoch 146/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1211 - accuracy: 0.9539
# Epoch 147/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1342 - accuracy: 0.9449
# Epoch 148/200
# 672/672 [==============================] - 1s 962us/step - loss: 0.1414 - accuracy: 0.9494
# Epoch 149/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1028 - accuracy: 0.9702
# Epoch 150/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1126 - accuracy: 0.9524
# Epoch 151/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1449 - accuracy: 0.9509
# Epoch 152/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1240 - accuracy: 0.9539
# Epoch 153/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1474 - accuracy: 0.9405
# Epoch 154/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1252 - accuracy: 0.9524
# Epoch 155/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0924 - accuracy: 0.9598
# Epoch 156/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1058 - accuracy: 0.9568
# Epoch 157/200
# 672/672 [==============================] - 1s 899us/step - loss: 0.1285 - accuracy: 0.9524
# Epoch 158/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1253 - accuracy: 0.9568
# Epoch 159/200
# 672/672 [==============================] - 1s 932us/step - loss: 0.0896 - accuracy: 0.9598
# Epoch 160/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1456 - accuracy: 0.9464
# Epoch 161/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1038 - accuracy: 0.9643
# Epoch 162/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1443 - accuracy: 0.9464
# Epoch 163/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1208 - accuracy: 0.9539
# Epoch 164/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0956 - accuracy: 0.9598
# Epoch 165/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1017 - accuracy: 0.9628
# Epoch 166/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0931 - accuracy: 0.9643
# Epoch 167/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1356 - accuracy: 0.9568
# Epoch 168/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1244 - accuracy: 0.9539
# Epoch 169/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1369 - accuracy: 0.9435
# Epoch 170/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1049 - accuracy: 0.9583
# Epoch 171/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1164 - accuracy: 0.9583
# Epoch 172/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1158 - accuracy: 0.9509
# Epoch 173/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0780 - accuracy: 0.9613
# Epoch 174/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1221 - accuracy: 0.9494
# Epoch 175/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1109 - accuracy: 0.9658
# Epoch 176/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0780 - accuracy: 0.9688
# Epoch 177/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0922 - accuracy: 0.9598
# Epoch 178/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0826 - accuracy: 0.9613
# Epoch 179/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1182 - accuracy: 0.9568
# Epoch 180/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1160 - accuracy: 0.9494
# Epoch 181/200
# 672/672 [==============================] - 1s 964us/step - loss: 0.0929 - accuracy: 0.9568
# Epoch 182/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1181 - accuracy: 0.9613
# Epoch 183/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1031 - accuracy: 0.9509
# Epoch 184/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0948 - accuracy: 0.9628
# Epoch 185/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0961 - accuracy: 0.9554
# Epoch 186/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1759 - accuracy: 0.9509
# Epoch 187/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0828 - accuracy: 0.9583
# Epoch 188/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0842 - accuracy: 0.9628
# Epoch 189/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1118 - accuracy: 0.9747
# Epoch 190/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1161 - accuracy: 0.9509
# Epoch 191/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1241 - accuracy: 0.9568
# Epoch 192/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0920 - accuracy: 0.9554
# Epoch 193/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1371 - accuracy: 0.9539
# Epoch 194/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.0967 - accuracy: 0.9583
# Epoch 195/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1970 - accuracy: 0.9449
# Epoch 196/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1489 - accuracy: 0.9509
# Epoch 197/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1104 - accuracy: 0.9509
# Epoch 198/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1566 - accuracy: 0.9405
# Epoch 199/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1334 - accuracy: 0.9554
# Epoch 200/200
# 672/672 [==============================] - 1s 1ms/step - loss: 0.1332 - accuracy: 0.9479

# %%
def clean_up_sentence(sentence):
    s_words = nltk.word_tokenize(sentence)
    s_words = [stemmer.stem(w.lower()) for w in s_words if w not in ignore_words]
    
    return s_words

def bow(sentence, words, show_details=True):
    s_words = clean_up_sentence(sentence)
    
    bag = [0 for _ in range(len(words))]
    
    for s in s_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                
                if show_details:
                    print(f"found in bag: {s}")
                    
    return np.array(bag)

def classify_local(sentence):
    ERROR_THRESHOLD = 0.25
    
    input_data = pd.DataFrame([bow(sentence, words, show_details=False)], dtype=float, index=['input'])
    results = model.predict([input_data])[0]
    
    #filter out prediction below a threshold, and provide intent index
    results = [[i, r] for i, r in enumerate(results) if r > ERROR_THRESHOLD]
    
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], str(r[1])))
    
    return return_list
    
while True:
    inp = input("You: ")
    
    if inp == 'quit' or inp == 'stop':
        break
        
    results = classify_local(inp)[0]
    
    for intent in data['intents']:
        if intent['tag'] == results[0]:
            responses = intent['responses']
    
    print(random.choice(responses))
# Out:
# You:  Hello
# Your _insert for today is _value.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/deeplearning/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~/anaconda3/envs/deeplearning/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/envs/deeplearning/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/envs/deeplearning/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c4a8736a25b5> in <module>
#      39
#      40 while True:
# ---> 41     inp = input("You: ")
#      42
#      43     if inp == 'quit' or inp == 'stop':
#
# ~/anaconda3/envs/deeplearning/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# ~/anaconda3/envs/deeplearning/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:
