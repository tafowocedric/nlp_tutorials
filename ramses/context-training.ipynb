# %% [markdown]
# # Import libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import pickle
import random
import json
import string
import re
import traceback

import tensorflow
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.stem.lancaster import LancasterStemmer
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, LSTM, Bidirectional, Reshape
from tensorflow.keras.optimizers import SGD
import sys
import os

# %% [markdown]
# # Constants

# %%
class ModelConstants:
    JSON_DATASET_PATH = "/home/rash/Documents/univers-py-api/ramses/data/kpi_identifier.json"
    PICKLE_DATASET_PATH = "/home/rash/Documents/univers-py-api/test-notebooks/data.pickle"
    TRAINING_CHECKPOINT_FILE_PATH = "/home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint"
    TRAINED_MODEL_PATH = "/home/rash/Documents/univers-py-api/test-notebooks/kpi_identifier.h5"
    RAMSES_ERROR_THRESHOLD = 0.6

# %% [markdown]
# # Build model

# %%
class Model:
    # Loading json dataset
    def __load_json_dataset__():
        try:
            with open(ModelConstants.JSON_DATASET_PATH, "rb") as file:
                data = json.load(file)

                return data

        except Exception as e:
            raise FileNotFoundError(f"{ModelConstants.DATASET_PATH} does not exist")
    
    # Loading pickle dataset
    def __load_pickle_dataset__():
        try:
            with open(ModelConstants.PICKLE_DATASET_PATH, 'rb') as file:
                words, classes, documents = pickle.load(file)

                return words, classes, documents

        except Exception as e:
            raise FileNotFoundError(f"{ModelConstants.PICKLE_DATASET_PATH} does not exist")

    
        
    __data__ = __load_json_dataset__()
    __words__, __classes__, __documents__ = [], [], []
    
    __stemmer__ = nltk.stem.LancasterStemmer()
    
    __loaded_words__, __loaded_classes__, __loaded_documents__ = __load_pickle_dataset__()
    __loaded_model__ = tensorflow.keras.models.load_model(ModelConstants.TRAINED_MODEL_PATH)

    
    def __init__(self):
        if Model.__model__ is not None:
            raise Exception("This class is a singleton!")

        else:
            Model.__model__ = self
    
    @staticmethod
    def __ignored_words__():
        return ["'s"] + [character for character in string.punctuation]
    
    @staticmethod
    def __callbacks__():
        my_callbacks = [
        #     tensorflow.keras.callbacks.EarlyStopping(monitor="loss", patience=10),
        #     tensorflow.keras.callbacks.TensorBoard(log_dir='./logs'),
            tensorflow.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.01, patience=10, min_lr=0.001, verbose=1),
            tensorflow.keras.callbacks.ModelCheckpoint(filepath=ModelConstants.TRAINING_CHECKPOINT_FILE_PATH, monitor='loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
        ]
        
        return my_callbacks
        
    @staticmethod
    def __clean_up_sentence__(sentence):
        s_words = nltk.word_tokenize(sentence)
        s_words = [Model.__stemmer__.stem(word.lower()) for word in s_words if
                   word not in Model.__ignored_words__()]

        return s_words

    @staticmethod
    def __bow__(sentence, words, show_details=True):
        s_words = Model.__clean_up_sentence__(sentence=sentence)

        bag = [0 for _ in range(len(words))]

        for s_word in s_words:
            for index, word in enumerate(words):
                if word == s_word:
                    bag[index] = 1

                    if show_details:
                        print(f"found in bag: {s_word}")

        return np.array(bag)

    @staticmethod
    def __classify_local__(sentence):
        ERROR_THRESHOLD = ModelConstants.RAMSES_ERROR_THRESHOLD

        input_data = pd.DataFrame(
            [Model.__bow__(sentence=sentence, words=Model.__loaded_words__, show_details=False)],
            dtype=float, index=['input'])
        input_data = input_data.values.reshape(-1, 1, input_data.shape[1])

        results = Model.__loaded_model__.predict([input_data])[0]
        context_probabilities = {}

        for index, probability in enumerate(results):
            context_probabilities[Model.__loaded_classes__[index]] = f"{round(probability, 4)}%"

        # filter out prediction below a threshold, and provide intent index
        results = [[index, result] for index, result in enumerate(results) if result > ERROR_THRESHOLD]

        # sort by strength of probability
        results.sort(key=lambda x: x[1], reverse=False)
        return_list = []

        for result in results:
            return_list.append((Model.__loaded_classes__[result[0]], str(result[1])))

        if not return_list: return None, context_probabilities

        return return_list[0], context_probabilities

    @staticmethod
    def __predict__(doc: str):
        try:
            results, context_probabilities = Model.__classify_local__(sentence=doc)
            
            for intent in Model.__data__["intents"]:
                if intent["tag"] == results[0]:
                    for query in doc.split():
                        for validate in intent["validate"]:
                            if Model.__stemmer__.stem(
                                    nltk.word_tokenize(query)[0]) == Model.__stemmer__.stem(validate):
                                return results[0], context_probabilities
                            elif results[0] == "definition" and re.search(r"""(?:is\s)\w{3,}""", doc):
                                return results[0], context_probabilities
                    return None, None
        
        except Exception:
            return None, None
    
    @staticmethod
    def __feature_engineering__():
        for intent in Model.__data__['intents']:
            for pattern in intent['patterns']:
                # tokenize each word in the sentence
                words = nltk.word_tokenize(pattern)
                Model.__words__.extend(words) # add to word list
                Model.__documents__.append((words, intent['tag'])) # add to documents in our corpus

            if intent['tag'] not in Model.__classes__:
                Model.__classes__.append(intent['tag']) # add to our class list

        # stem and lower each word and remove duplicates
        Model.__words__ = [Model.__stemmer__.stem(word.lower()) for word in Model.__words__ if word not in Model.__ignored_words__()]
        Model.__words__ = sorted(list(set(Model.__words__)))

        Model.__classes__ = sorted(list(set(Model.__classes__))) # sort classes

        print(f"{len(Model.__documents__)} documents\n{len(Model.__classes__)} classes\n{len(Model.__words__)} unique stemmed words")

        with open(ModelConstants.PICKLE_DATASET_PATH, 'wb') as file:
            pickle.dump((Model.__words__, Model.__classes__, Model.__documents__), file)
    
    @staticmethod
    def __normalize__():
        training = []
        output_empty = [0 for _ in range(len(Model.__classes__))]

        for doc in Model.__documents__: # bag of words
            bag = []
            s_words = [Model.__stemmer__.stem(word.lower()) for word in doc[0] if word not in Model.__ignored_words__()]

            for word in Model.__words__:
                bag.append(1) if word in s_words else bag.append(0)

            output_row = output_empty[:]
            output_row[Model.__classes__.index(doc[1])] = 1

            training.append([bag, output_row])

        # shuffle our features and turn intp np.array
        random.shuffle(training)
        training = np.array(training)

        # create train and test list.
        train_x = tensorflow.cast(np.array(list(training[:, 0])), tensorflow.float32)
        train_y = tensorflow.cast(np.array(list(training[:, 1])), tensorflow.float32)

        train_x = tensorflow.reshape(train_x, (train_x.shape[0], 1, train_x.shape[1]))
        print(f"{train_x.shape} {train_y.shape}")
        
        return train_x, train_y
    
    @staticmethod
    def __build__(train_x, train_y):
        # Build Model
        model = Sequential()
        model.add(LSTM(units=train_x.shape[2], input_shape=(1, train_x.shape[2])))
        model.add(Dropout(0.2))

        model.add(Dense(128, activation="relu"))
        model.add(Dropout(0.2))

        model.add(Dense(64, activation="relu"))
        model.add(Dropout(0.2))

        model.add(Dense(train_y.shape[1], activation="softmax"))
        
        return model
    
    @staticmethod
    def __train__(epochs: int, batch_size: int, save_model: bool, verbose: int = 1):
        # Feature Engineering on data
        Model.__feature_engineering__()
        
        # Normalize data
        train_x, train_y = Model.__normalize__()
        
        # Build Model
        model = Model.__build__(train_x=train_x, train_y=train_y)

        # Model Optimizer
        sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

        if not tf.io.gfile.exists(ModelConstants.TRAINING_CHECKPOINT_FILE_PATH):
            print("\n============================= Create a new model =============================\n")
            model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
        
        else:
            print("\n============================= Load existing model weights =============================\n")
            model = tf.keras.models.load_model(ModelConstants.TRAINED_MODEL_PATH)
            model.load_weights(ModelConstants.TRAINING_CHECKPOINT_FILE_PATH)


        # Fit the model
        model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=Model.__callbacks__())
        
        if save_model:
            Model.__save__(model=model)
            
        return model
    
    @staticmethod
    def __save__(model: object):
        model.load_weights(ModelConstants.TRAINING_CHECKPOINT_FILE_PATH)
        model.save(ModelConstants.TRAINED_MODEL_PATH)
        
        return
    
    @staticmethod
    def __validate_helper__():
        predictions, wrong_predictions = [], []
        accuracy, recall, precision, f_score = [], [], [], []
        
        for intent in Model.__data__["intents"]:
            prediction_dict = {}
            
            for pattern in intent["patterns"]:
                # Model prediction
                context, probabilties = Model.predict(doc=pattern)
                
                prediction_dict["text"] = pattern
                prediction_dict["actual"] = intent.get("tag")
                prediction_dict["predicted"] = context
                prediction_dict["accuracy"] = probabilties.get(context) if probabilties is not None else None
                
                predictions.append(prediction_dict)
        
        for prediction in predictions:
            print(f"Question: {prediction.get('text')} \t Actual: {prediction.get('actual')} \t Predicted: {prediction.get('predicted')} \t Accuracy: {prediction.get('accuracy')}")
            
            if prediction.get("actual") != prediction.get("predicted"):
                wrong_predictions.append(prediction)
            
        wrong_predictions = [prediction for prediction in predictions if prediction.get("actual") != prediction.get("predicted")]
        return True if not wrong_predictions else False

    @staticmethod
    def train(epochs: int = 20, batch_size: int = 1, save_model: bool = True):
        model = Model.__train__(epochs=epochs, batch_size=batch_size, save_model=save_model)
        return model
    
    @staticmethod
    def predict(doc: str):
        if Model.__loaded_model__ is None:
            Model()

        return Model.__predict__(doc=doc)
    
    
    @staticmethod
    def validate():
        if Model.__loaded_model__ is None:
            Model()

        return Model.__validate_helper__()

# %%
# model = Model.train(epochs=200)
# Out:
# 639 documents
# 12 classes
# 163 unique stemmed words
# (639, 1, 163) (639, 12)
#
# ============================= Load existing model weights =============================
#
# Epoch 1/200
# 639/639 [==============================] - 2s 2ms/step - loss: 7.0863e-04 - accuracy: 1.0000
#
# Epoch 00001: loss improved from inf to 0.00071, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 2/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 1.0000
#
# Epoch 00002: loss did not improve from 0.00071
# Epoch 3/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00003: loss did not improve from 0.00071
# Epoch 4/200
# 639/639 [==============================] - 2s 2ms/step - loss: 9.4142e-04 - accuracy: 1.0000
#
# Epoch 00004: loss did not improve from 0.00071
# Epoch 5/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0019 - accuracy: 1.0000
#
# Epoch 00005: loss did not improve from 0.00071
# Epoch 6/200
# 639/639 [==============================] - 2s 2ms/step - loss: 7.2980e-04 - accuracy: 1.0000
#
# Epoch 00006: loss did not improve from 0.00071
# Epoch 7/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.6570e-04 - accuracy: 1.0000
#
# Epoch 00007: loss improved from 0.00071 to 0.00047, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 8/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00008: loss did not improve from 0.00047
# Epoch 9/200
# 639/639 [==============================] - 2s 3ms/step - loss: 7.4202e-04 - accuracy: 1.0000
#
# Epoch 00009: loss did not improve from 0.00047
# Epoch 10/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00010: loss did not improve from 0.00047
# Epoch 11/200
# 639/639 [==============================] - 2s 2ms/step - loss: 8.3699e-04 - accuracy: 1.0000
#
# Epoch 00011: loss did not improve from 0.00047
# Epoch 12/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 1.0000
#
# Epoch 00012: loss did not improve from 0.00047
# Epoch 13/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.9923e-04 - accuracy: 1.0000
#
# Epoch 00013: loss did not improve from 0.00047
# Epoch 14/200
# 639/639 [==============================] - 2s 2ms/step - loss: 7.0387e-04 - accuracy: 1.0000
#
# Epoch 00014: loss did not improve from 0.00047
# Epoch 15/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.1926e-04 - accuracy: 1.0000
#
# Epoch 00015: loss did not improve from 0.00047
# Epoch 16/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00016: loss did not improve from 0.00047
# Epoch 17/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 1.0000
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00017: loss did not improve from 0.00047
# Epoch 18/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.7125e-04 - accuracy: 1.0000
#
# Epoch 00018: loss did not improve from 0.00047
# Epoch 19/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.6859e-04 - accuracy: 1.0000
#
# Epoch 00019: loss did not improve from 0.00047
# Epoch 20/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00020: loss did not improve from 0.00047
# Epoch 21/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00021: loss did not improve from 0.00047
# Epoch 22/200
# 639/639 [==============================] - 2s 2ms/step - loss: 8.2429e-04 - accuracy: 1.0000
#
# Epoch 00022: loss did not improve from 0.00047
# Epoch 23/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.9865e-04 - accuracy: 1.0000
#
# Epoch 00023: loss did not improve from 0.00047
# Epoch 24/200
# 639/639 [==============================] - 2s 2ms/step - loss: 5.8488e-04 - accuracy: 1.0000
#
# Epoch 00024: loss did not improve from 0.00047
# Epoch 25/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00025: loss did not improve from 0.00047
# Epoch 26/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.4881e-04 - accuracy: 1.0000
#
# Epoch 00026: loss did not improve from 0.00047
# Epoch 27/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.1106e-04 - accuracy: 1.0000
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00027: loss did not improve from 0.00047
# Epoch 28/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.8782e-04 - accuracy: 1.0000
#
# Epoch 00028: loss did not improve from 0.00047
# Epoch 29/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.4007e-04 - accuracy: 1.0000
#
# Epoch 00029: loss improved from 0.00047 to 0.00034, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 30/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.2392e-04 - accuracy: 1.0000
#
# Epoch 00030: loss did not improve from 0.00034
# Epoch 31/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00031: loss did not improve from 0.00034
# Epoch 32/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.1025e-04 - accuracy: 1.0000
#
# Epoch 00032: loss did not improve from 0.00034
# Epoch 33/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0030 - accuracy: 0.9984
#
# Epoch 00033: loss did not improve from 0.00034
# Epoch 34/200
# 639/639 [==============================] - 2s 3ms/step - loss: 7.2005e-04 - accuracy: 1.0000
#
# Epoch 00034: loss did not improve from 0.00034
# Epoch 35/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.2831e-04 - accuracy: 1.0000
#
# Epoch 00035: loss did not improve from 0.00034
# Epoch 36/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0039 - accuracy: 0.9984
#
# Epoch 00036: loss did not improve from 0.00034
# Epoch 37/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0027 - accuracy: 1.0000
#
# Epoch 00037: loss did not improve from 0.00034
# Epoch 38/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00038: loss did not improve from 0.00034
# Epoch 39/200
# 639/639 [==============================] - 1s 2ms/step - loss: 9.7167e-04 - accuracy: 1.0000
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00039: loss did not improve from 0.00034
# Epoch 40/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00040: loss did not improve from 0.00034
# Epoch 41/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00041: loss did not improve from 0.00034
# Epoch 42/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.5070e-04 - accuracy: 1.0000
#
# Epoch 00042: loss did not improve from 0.00034
# Epoch 43/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.4991e-04 - accuracy: 1.0000
#
# Epoch 00043: loss did not improve from 0.00034
# Epoch 44/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.6484e-04 - accuracy: 1.0000
#
# Epoch 00044: loss did not improve from 0.00034
# Epoch 45/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00045: loss did not improve from 0.00034
# Epoch 46/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.2408e-04 - accuracy: 1.0000
#
# Epoch 00046: loss did not improve from 0.00034
# Epoch 47/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00047: loss did not improve from 0.00034
# Epoch 48/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.9443e-04 - accuracy: 1.0000
#
# Epoch 00048: loss did not improve from 0.00034
# Epoch 49/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.2948e-04 - accuracy: 1.0000
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00049: loss did not improve from 0.00034
# Epoch 50/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.6471e-04 - accuracy: 1.0000
#
# Epoch 00050: loss did not improve from 0.00034
# Epoch 51/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00051: loss did not improve from 0.00034
# Epoch 52/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00052: loss did not improve from 0.00034
# Epoch 53/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00053: loss did not improve from 0.00034
# Epoch 54/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.0913e-04 - accuracy: 1.0000
#
# Epoch 00054: loss did not improve from 0.00034
# Epoch 55/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.2053e-04 - accuracy: 1.0000
#
# Epoch 00055: loss did not improve from 0.00034
# Epoch 56/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.7120e-04 - accuracy: 1.0000
#
# Epoch 00056: loss did not improve from 0.00034
# Epoch 57/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.4709e-04 - accuracy: 1.0000
#
# Epoch 00057: loss did not improve from 0.00034
# Epoch 58/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.7196e-04 - accuracy: 1.0000
#
# Epoch 00058: loss did not improve from 0.00034
# Epoch 59/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.7688e-04 - accuracy: 1.0000
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00059: loss did not improve from 0.00034
# Epoch 60/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00060: loss did not improve from 0.00034
# Epoch 61/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00061: loss did not improve from 0.00034
# Epoch 62/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.8321e-04 - accuracy: 1.0000
#
# Epoch 00062: loss did not improve from 0.00034
# Epoch 63/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00063: loss did not improve from 0.00034
# Epoch 64/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.7701e-04 - accuracy: 1.0000
#
# Epoch 00064: loss did not improve from 0.00034
# Epoch 65/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.5245e-04 - accuracy: 1.0000
#
# Epoch 00065: loss did not improve from 0.00034
# Epoch 66/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 0.9984
#
# Epoch 00066: loss did not improve from 0.00034
# Epoch 67/200
# 639/639 [==============================] - 2s 3ms/step - loss: 7.6741e-04 - accuracy: 1.0000
#
# Epoch 00067: loss did not improve from 0.00034
# Epoch 68/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00068: loss did not improve from 0.00034
# Epoch 69/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.2599e-04 - accuracy: 1.0000
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00069: loss did not improve from 0.00034
# Epoch 70/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.6323e-04 - accuracy: 1.0000
#
# Epoch 00070: loss did not improve from 0.00034
# Epoch 71/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.6905e-04 - accuracy: 1.0000
#
# Epoch 00071: loss did not improve from 0.00034
# Epoch 72/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.1990e-04 - accuracy: 1.0000
#
# Epoch 00072: loss did not improve from 0.00034
# Epoch 73/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0020 - accuracy: 1.0000
#
# Epoch 00073: loss did not improve from 0.00034
# Epoch 74/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.9166e-04 - accuracy: 1.0000
#
# Epoch 00074: loss did not improve from 0.00034
# Epoch 75/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.5154e-04 - accuracy: 1.0000
#
# Epoch 00075: loss did not improve from 0.00034
# Epoch 76/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.0303e-04 - accuracy: 1.0000
#
# Epoch 00076: loss did not improve from 0.00034
# Epoch 77/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00077: loss did not improve from 0.00034
# Epoch 78/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.0127e-04 - accuracy: 1.0000
#
# Epoch 00078: loss did not improve from 0.00034
# Epoch 79/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00079: loss did not improve from 0.00034
# Epoch 80/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.7730e-04 - accuracy: 1.0000
#
# Epoch 00080: loss did not improve from 0.00034
# Epoch 81/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.2899e-04 - accuracy: 1.0000
#
# Epoch 00081: loss did not improve from 0.00034
# Epoch 82/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.4968e-04 - accuracy: 1.0000
#
# Epoch 00082: loss did not improve from 0.00034
# Epoch 83/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.8621e-04 - accuracy: 1.0000
#
# Epoch 00083: loss did not improve from 0.00034
# Epoch 84/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00084: loss did not improve from 0.00034
# Epoch 85/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00085: loss did not improve from 0.00034
# Epoch 86/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.5069e-04 - accuracy: 1.0000
#
# Epoch 00086: loss did not improve from 0.00034
# Epoch 87/200
# 639/639 [==============================] - 1s 2ms/step - loss: 9.3328e-04 - accuracy: 1.0000
#
# Epoch 00087: loss did not improve from 0.00034
# Epoch 88/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00088: loss did not improve from 0.00034
# Epoch 89/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.6459e-04 - accuracy: 1.0000
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00089: loss did not improve from 0.00034
# Epoch 90/200
# 639/639 [==============================] - 1s 2ms/step - loss: 9.7000e-04 - accuracy: 1.0000
#
# Epoch 00090: loss did not improve from 0.00034
# Epoch 91/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.0491e-04 - accuracy: 1.0000
#
# Epoch 00091: loss improved from 0.00034 to 0.00030, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 92/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00092: loss did not improve from 0.00030
# Epoch 93/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.2103e-04 - accuracy: 1.0000
#
# Epoch 00093: loss did not improve from 0.00030
# Epoch 94/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.7672e-04 - accuracy: 1.0000
#
# Epoch 00094: loss did not improve from 0.00030
# Epoch 95/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.1010e-04 - accuracy: 1.0000
#
# Epoch 00095: loss did not improve from 0.00030
# Epoch 96/200
# 639/639 [==============================] - 2s 3ms/step - loss: 2.9692e-04 - accuracy: 1.0000
#
# Epoch 00096: loss improved from 0.00030 to 0.00030, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 97/200
# 639/639 [==============================] - 2s 2ms/step - loss: 5.2184e-04 - accuracy: 1.0000
#
# Epoch 00097: loss did not improve from 0.00030
# Epoch 98/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00098: loss did not improve from 0.00030
# Epoch 99/200
# 639/639 [==============================] - 2s 3ms/step - loss: 8.5901e-04 - accuracy: 1.0000
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00099: loss did not improve from 0.00030
# Epoch 100/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0024 - accuracy: 0.9984
#
# Epoch 00100: loss did not improve from 0.00030
# Epoch 101/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.9495e-04 - accuracy: 1.0000
#
# Epoch 00101: loss did not improve from 0.00030
# Epoch 102/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.4351e-04 - accuracy: 1.0000
#
# Epoch 00102: loss did not improve from 0.00030
# Epoch 103/200
# 639/639 [==============================] - 2s 2ms/step - loss: 8.3169e-04 - accuracy: 1.0000
#
# Epoch 00103: loss did not improve from 0.00030
# Epoch 104/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00104: loss did not improve from 0.00030
# Epoch 105/200
# 639/639 [==============================] - 2s 2ms/step - loss: 2.8578e-04 - accuracy: 1.0000
#
# Epoch 00105: loss improved from 0.00030 to 0.00029, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 106/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.1701e-04 - accuracy: 1.0000
#
# Epoch 00106: loss did not improve from 0.00029
# Epoch 107/200
# 639/639 [==============================] - 1s 2ms/step - loss: 9.6949e-04 - accuracy: 1.0000
#
# Epoch 00107: loss did not improve from 0.00029
# Epoch 108/200
# 639/639 [==============================] - 2s 3ms/step - loss: 8.5666e-04 - accuracy: 1.0000
#
# Epoch 00108: loss did not improve from 0.00029
# Epoch 109/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.9163e-04 - accuracy: 1.0000
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00109: loss did not improve from 0.00029
# Epoch 110/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00110: loss did not improve from 0.00029
# Epoch 111/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9984
#
# Epoch 00111: loss did not improve from 0.00029
# Epoch 112/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.1822e-04 - accuracy: 1.0000
#
# Epoch 00112: loss did not improve from 0.00029
# Epoch 113/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.7006e-04 - accuracy: 1.0000
#
# Epoch 00113: loss did not improve from 0.00029
# Epoch 114/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.6571e-04 - accuracy: 1.0000
#
# Epoch 00114: loss did not improve from 0.00029
# Epoch 115/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.0710e-04 - accuracy: 1.0000
#
# Epoch 00115: loss did not improve from 0.00029
# Epoch 116/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00116: loss did not improve from 0.00029
# Epoch 117/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0026 - accuracy: 0.9984
#
# Epoch 00117: loss did not improve from 0.00029
# Epoch 118/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.9537e-04 - accuracy: 1.0000
#
# Epoch 00118: loss did not improve from 0.00029
# Epoch 119/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.2583e-04 - accuracy: 1.0000
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00119: loss did not improve from 0.00029
# Epoch 120/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.0471e-04 - accuracy: 1.0000
#
# Epoch 00120: loss did not improve from 0.00029
# Epoch 121/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.4339e-04 - accuracy: 1.0000
#
# Epoch 00121: loss did not improve from 0.00029
# Epoch 122/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.2549e-04 - accuracy: 1.0000
#
# Epoch 00122: loss did not improve from 0.00029
# Epoch 123/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.7941e-04 - accuracy: 1.0000
#
# Epoch 00123: loss did not improve from 0.00029
# Epoch 124/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.0694e-04 - accuracy: 1.0000
#
# Epoch 00124: loss did not improve from 0.00029
# Epoch 125/200
# 639/639 [==============================] - 1s 2ms/step - loss: 2.9278e-04 - accuracy: 1.0000
#
# Epoch 00125: loss did not improve from 0.00029
# Epoch 126/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.0641e-04 - accuracy: 1.0000
#
# Epoch 00126: loss did not improve from 0.00029
# Epoch 127/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.4554e-04 - accuracy: 1.0000
#
# Epoch 00127: loss did not improve from 0.00029
# Epoch 128/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.5014e-04 - accuracy: 1.0000
#
# Epoch 00128: loss did not improve from 0.00029
# Epoch 129/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.3643e-04 - accuracy: 1.0000
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00129: loss did not improve from 0.00029
# Epoch 130/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.4793e-04 - accuracy: 1.0000
#
# Epoch 00130: loss did not improve from 0.00029
# Epoch 131/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.7898e-04 - accuracy: 1.0000
#
# Epoch 00131: loss did not improve from 0.00029
# Epoch 132/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.0076e-04 - accuracy: 1.0000
#
# Epoch 00132: loss did not improve from 0.00029
# Epoch 133/200
# 639/639 [==============================] - 1s 2ms/step - loss: 2.5846e-04 - accuracy: 1.0000
#
# Epoch 00133: loss improved from 0.00029 to 0.00026, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 134/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00134: loss did not improve from 0.00026
# Epoch 135/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.3748e-04 - accuracy: 1.0000
#
# Epoch 00135: loss did not improve from 0.00026
# Epoch 136/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.1466e-04 - accuracy: 1.0000
#
# Epoch 00136: loss did not improve from 0.00026
# Epoch 137/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00137: loss did not improve from 0.00026
# Epoch 138/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.8264e-04 - accuracy: 1.0000
#
# Epoch 00138: loss did not improve from 0.00026
# Epoch 139/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.9804e-04 - accuracy: 1.0000
#
# Epoch 00139: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00139: loss did not improve from 0.00026
# Epoch 140/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00140: loss did not improve from 0.00026
# Epoch 141/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.9969
#
# Epoch 00141: loss did not improve from 0.00026
# Epoch 142/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.7652e-04 - accuracy: 1.0000
#
# Epoch 00142: loss did not improve from 0.00026
# Epoch 143/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00143: loss did not improve from 0.00026
# Epoch 144/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.2115e-04 - accuracy: 1.0000
#
# Epoch 00144: loss did not improve from 0.00026
# Epoch 145/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.4312e-04 - accuracy: 1.0000
#
# Epoch 00145: loss did not improve from 0.00026
# Epoch 146/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00146: loss did not improve from 0.00026
# Epoch 147/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00147: loss did not improve from 0.00026
# Epoch 148/200
# 639/639 [==============================] - 1s 2ms/step - loss: 9.8653e-04 - accuracy: 1.0000
#
# Epoch 00148: loss did not improve from 0.00026
# Epoch 149/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.8186e-04 - accuracy: 1.0000
#
# Epoch 00149: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00149: loss did not improve from 0.00026
# Epoch 150/200
# 639/639 [==============================] - 1s 2ms/step - loss: 2.8304e-04 - accuracy: 1.0000
#
# Epoch 00150: loss did not improve from 0.00026
# Epoch 151/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.8635e-04 - accuracy: 1.0000
#
# Epoch 00151: loss did not improve from 0.00026
# Epoch 152/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00152: loss did not improve from 0.00026
# Epoch 153/200
# 639/639 [==============================] - 1s 2ms/step - loss: 7.2195e-04 - accuracy: 1.0000
#
# Epoch 00153: loss did not improve from 0.00026
# Epoch 154/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00154: loss did not improve from 0.00026
# Epoch 155/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00155: loss did not improve from 0.00026
# Epoch 156/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.5409e-04 - accuracy: 1.0000
#
# Epoch 00156: loss did not improve from 0.00026
# Epoch 157/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 1.0000
#
# Epoch 00157: loss did not improve from 0.00026
# Epoch 158/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.2315e-04 - accuracy: 1.0000
#
# Epoch 00158: loss did not improve from 0.00026
# Epoch 159/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 1.0000
#
# Epoch 00159: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00159: loss did not improve from 0.00026
# Epoch 160/200
# 639/639 [==============================] - 2s 3ms/step - loss: 7.2994e-04 - accuracy: 1.0000
#
# Epoch 00160: loss did not improve from 0.00026
# Epoch 161/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.2773e-04 - accuracy: 1.0000
#
# Epoch 00161: loss did not improve from 0.00026
# Epoch 162/200
# 639/639 [==============================] - 2s 2ms/step - loss: 3.7979e-04 - accuracy: 1.0000
#
# Epoch 00162: loss did not improve from 0.00026
# Epoch 163/200
# 639/639 [==============================] - 2s 3ms/step - loss: 5.8463e-04 - accuracy: 1.0000
#
# Epoch 00163: loss did not improve from 0.00026
# Epoch 164/200
# 639/639 [==============================] - 2s 3ms/step - loss: 5.9021e-04 - accuracy: 1.0000
#
# Epoch 00164: loss did not improve from 0.00026
# Epoch 165/200
# 639/639 [==============================] - 2s 4ms/step - loss: 3.9075e-04 - accuracy: 1.0000
#
# Epoch 00165: loss did not improve from 0.00026
# Epoch 166/200
# 639/639 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00166: loss did not improve from 0.00026
# Epoch 167/200
# 639/639 [==============================] - 3s 5ms/step - loss: 4.2424e-04 - accuracy: 1.0000
#
# Epoch 00167: loss did not improve from 0.00026
# Epoch 168/200
# 639/639 [==============================] - 2s 3ms/step - loss: 7.5398e-04 - accuracy: 1.0000
#
# Epoch 00168: loss did not improve from 0.00026
# Epoch 169/200
# 639/639 [==============================] - 2s 3ms/step - loss: 4.9324e-04 - accuracy: 1.0000
#
# Epoch 00169: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00169: loss did not improve from 0.00026
# Epoch 170/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00170: loss did not improve from 0.00026
# Epoch 171/200
# 639/639 [==============================] - 1s 2ms/step - loss: 9.7840e-04 - accuracy: 1.0000
#
# Epoch 00171: loss did not improve from 0.00026
# Epoch 172/200
# 639/639 [==============================] - 2s 2ms/step - loss: 0.0022 - accuracy: 0.9984
#
# Epoch 00172: loss did not improve from 0.00026
# Epoch 173/200
# 639/639 [==============================] - 2s 3ms/step - loss: 3.2424e-04 - accuracy: 1.0000
#
# Epoch 00173: loss did not improve from 0.00026
# Epoch 174/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 1.0000
#
# Epoch 00174: loss did not improve from 0.00026
# Epoch 175/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00175: loss did not improve from 0.00026
# Epoch 176/200
# 639/639 [==============================] - 2s 2ms/step - loss: 2.5838e-04 - accuracy: 1.0000
#
# Epoch 00176: loss improved from 0.00026 to 0.00026, saving model to /home/rash/Documents/univers-py-api/test-notebooks/tmp/checkpoint
# Epoch 177/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.0513e-04 - accuracy: 1.0000
#
# Epoch 00177: loss did not improve from 0.00026
# Epoch 178/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.3294e-04 - accuracy: 1.0000
#
# Epoch 00178: loss did not improve from 0.00026
# Epoch 179/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.7830e-04 - accuracy: 1.0000
#
# Epoch 00179: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00179: loss did not improve from 0.00026
# Epoch 180/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9984
#
# Epoch 00180: loss did not improve from 0.00026
# Epoch 181/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.9248e-04 - accuracy: 1.0000
#
# Epoch 00181: loss did not improve from 0.00026
# Epoch 182/200
# 639/639 [==============================] - 1s 2ms/step - loss: 8.4043e-04 - accuracy: 1.0000
#
# Epoch 00182: loss did not improve from 0.00026
# Epoch 183/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.0462e-04 - accuracy: 1.0000
#
# Epoch 00183: loss did not improve from 0.00026
# Epoch 184/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.3952e-04 - accuracy: 1.0000
#
# Epoch 00184: loss did not improve from 0.00026
# Epoch 185/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 1.0000
#
# Epoch 00185: loss did not improve from 0.00026
# Epoch 186/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.0057e-04 - accuracy: 1.0000
#
# Epoch 00186: loss did not improve from 0.00026
# Epoch 187/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.1399e-04 - accuracy: 1.0000
#
# Epoch 00187: loss did not improve from 0.00026
# Epoch 188/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.9842e-04 - accuracy: 1.0000
#
# Epoch 00188: loss did not improve from 0.00026
# Epoch 189/200
# 639/639 [==============================] - 1s 2ms/step - loss: 5.3584e-04 - accuracy: 1.0000
#
# Epoch 00189: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00189: loss did not improve from 0.00026
# Epoch 190/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.9776e-04 - accuracy: 1.0000
#
# Epoch 00190: loss did not improve from 0.00026
# Epoch 191/200
# 639/639 [==============================] - 1s 2ms/step - loss: 2.7434e-04 - accuracy: 1.0000
#
# Epoch 00191: loss did not improve from 0.00026
# Epoch 192/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.1668e-04 - accuracy: 1.0000
#
# Epoch 00192: loss did not improve from 0.00026
# Epoch 193/200
# 639/639 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00193: loss did not improve from 0.00026
# Epoch 194/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00194: loss did not improve from 0.00026
# Epoch 195/200
# 639/639 [==============================] - 1s 2ms/step - loss: 6.2900e-04 - accuracy: 1.0000
#
# Epoch 00195: loss did not improve from 0.00026
# Epoch 196/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00196: loss did not improve from 0.00026
# Epoch 197/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.7444e-04 - accuracy: 1.0000
#
# Epoch 00197: loss did not improve from 0.00026
# Epoch 198/200
# 639/639 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9984
#
# Epoch 00198: loss did not improve from 0.00026
# Epoch 199/200
# 639/639 [==============================] - 1s 2ms/step - loss: 3.6400e-04 - accuracy: 1.0000
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00199: loss did not improve from 0.00026
# Epoch 200/200
# 639/639 [==============================] - 1s 2ms/step - loss: 4.2868e-04 - accuracy: 1.0000
#
# Epoch 00200: loss did not improve from 0.00026

# %%
# Model.predict(doc="what is my revenue for today?")
# Model.validate()
# Out:
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: month forecast revenue 	 Actual: forecast 	 Predicted: forecast 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear income 	 Actual: revenue 	 Predicted: revenue 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear net income 	 Actual: margin 	 Predicted: margin 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: ayear spending 	 Actual: expense 	 Predicted: expense 	 Accuracy: 1.0%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: greetings 	 Actual: greetings 	 Predicted: greetings 	 Accuracy: 0.9997000098228455%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: insight guidance you provide 	 Actual: appreciation 	 Predicted: appreciation 	 Accuracy: 1.0%
# Question: call you 	 Actual: name 	 Predicted: name 	 Accuracy: 0.9975000023841858%
# Question: call you 	 Actual: name 	 Predicted: name 	 Accuracy: 0.9975000023841858%
# Question: call you 	 Actual: name 	 Predicted: name 	 Accuracy: 0.9975000023841858%
# Question: call you 	 Actual: name 	 Predicted: name 	 Accuracy: 0.9975000023841858%
# Question: call you 	 Actual: name 	 Predicted: name 	 Accuracy: 0.9975000023841858%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: do with you 	 Actual: help 	 Predicted: help 	 Accuracy: 0.9993000030517578%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: your health 	 Actual: state 	 Predicted: state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: things 	 Actual: business_state 	 Predicted: business_state 	 Accuracy: 0.9998999834060669%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: unpaid overdue invoice statistics 	 Actual: invoice 	 Predicted: invoice 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# Question: how are we doing on refund 	 Actual: refund 	 Predicted: refund 	 Accuracy: 1.0%
# True
